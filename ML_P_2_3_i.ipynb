# %% [markdown]
# <a href="https://colab.research.google.com/github/ai-veritas/ml-labs/blob/main/ML_P_2_3_i.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.datasets import load_breast_cancer

# %%
dataset = load_breast_cancer()
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df['target'] = dataset.target
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
X = df.drop('target', axis=1)
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(pd.DataFrame(X_train_scaled, columns=X_train.columns).head())
print(pd.DataFrame(X_test_scaled, columns=X_test.columns).head())
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0     3.673635      0.611448        3.661009   4.442548         0.894196
# 1    -1.329113     -1.646986       -1.318868  -1.087704         0.399795
# 2    -0.963141     -2.300806       -0.974089  -0.853464        -0.056466
# 3    -0.644045      0.530020       -0.656711  -0.626780         0.066428
# 4     0.604100      0.951530        0.671283   0.497685         0.048065
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          1.593210        2.444215             3.513755      -0.065652
# 1         -0.770151       -0.752876            -0.743368      -0.011393
# 2         -0.911415       -0.805636            -0.839704      -1.581306
# 3         -0.516587       -0.706696            -0.760699      -0.470791
# 4          0.814019        1.128335             0.963406       1.290840
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %% [markdown]
# ### KNN (3,5,7)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier(n_neighbors=3)

# %%
knn_model.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_pred = knn_model.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1-score: {f1:.4f}')
# Out:
# Accuracy: 0.9474
# Precision: 0.9577
# Recall: 0.9577
# F1-score: 0.9577

# %%
knn5 = KNeighborsClassifier(n_neighbors=5)
knn5.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn5.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1-score: {f1:.4f}')
# Out:
# Accuracy: 0.9474
# Precision: 0.9577
# Recall: 0.9577
# F1-score: 0.9577

# %%
knn7 = KNeighborsClassifier(n_neighbors=7)
knn7.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred = knn7.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1-score: {f1:.4f}')
# Out:
# Accuracy: 0.9474
# Precision: 0.9577
# Recall: 0.9577
# F1-score: 0.9577

# %% [markdown]
# ### KNN with Normalisation

# %%
from sklearn.preprocessing import Normalizer

normalizer = Normalizer()
X_train_normalized = normalizer.fit_transform(X_train)
X_test_normalized = normalizer.transform(X_test)

# %%
knn_normalised = KNeighborsClassifier(n_neighbors=3)
knn_normalised.fit(X_train_normalized, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn_normalised.predict(X_test_normalized)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1-score: {f1:.4f}')
# Out:
# Accuracy: 0.9386
# Precision: 0.9211
# Recall: 0.9859
# F1-score: 0.9524

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, random_state=25)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=25)

# %%
y_pred = rf_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)
# Out:
# Accuracy:  0.9649122807017544
# Precision:  0.958904109589041
# Recall:  0.9859154929577465
# F1 Score:  0.9722222222222222

# %%
from sklearn.preprocessing import Normalizer

normalizer = Normalizer()
X_train_normalized = normalizer.fit_transform(X_train)
X_test_normalized = normalizer.transform(X_test)

# %%
rf_norm = RandomForestClassifier(n_estimators=100, random_state=25)
rf_norm.fit(X_train_normalized, y_train)
# Out:
# RandomForestClassifier(random_state=25)

# %%
y_pred = rf_norm.predict(X_test_normalized)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)
# Out:
# Accuracy:  0.9736842105263158
# Precision:  0.9722222222222222
# Recall:  0.9859154929577465
# F1 Score:  0.9790209790209791

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, random_state=25)
rf_model.fit(X_train_pca, y_train)
# Out:
# RandomForestClassifier(random_state=25)

# %%
y_pred = rf_model.predict(X_test_pca)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)
# Out:
# Accuracy:  0.9473684210526315
# Precision:  0.9452054794520548
# Recall:  0.971830985915493
# F1 Score:  0.9583333333333334

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
plt.scatter(X_train_pca[:, 0], X_train_pca[:, 1], c=y_train, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
# Out:
# Text(0, 0.5, 'Principal Component 2')

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
print(confusion_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Predicted   0   1
# Actual
# 0          39   4
# 1           2  69

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = nb_model.predict(X_test)

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)
# Out:
# Accuracy:  0.9122807017543859
# Precision:  0.9452054794520548
# Recall:  0.92
# F1 Score:  0.9324324324324325

# %%
from sklearn.preprocessing import Normalizer

normalizer = Normalizer()
X_train_normalized = normalizer.fit_transform(X_train)
X_test_normalized = normalizer.transform(X_test)

nb_model_norm = GaussianNB()
nb_model_norm.fit(X_train_normalized, y_train)
y_pred_norm = nb_model_norm.predict(X_test_normalized)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Normalised Accuracy for Naive Bayes: ", accuracy)
print("Normalised Precision for Naive Bayes: ", precision)
print("Normalised Recall for Naive Bayes: ", recall)
print("Normalised F1 Score for Naive Bayes: ", f1)
# Out:
# Normalised Accuracy for Naive Bayes:  0.9122807017543859
# Normalised Precision for Naive Bayes:  0.9452054794520548
# Normalised Recall for Naive Bayes:  0.92
# Normalised F1 Score for Naive Bayes:  0.9324324324324325

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
nb_model_scaler = GaussianNB()
nb_model_scaler.fit(X_train_scaled, y_train)
y_pred_scaler = nb_model_scaler.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Standardized accuracy for Naive Bayes: ", accuracy)
print("Standardized precision for Naive Bayes: ", precision)
print("Standardized recall for Naive Bayes: ", recall)
print("Standardized F1 Score for Naive Bayes: ", f1)
# Out:
# Standardized accuracy for Naive Bayes:  0.9122807017543859
# Standardized precision for Naive Bayes:  0.9452054794520548
# Standardized recall for Naive Bayes:  0.92
# Standardized F1 Score for Naive Bayes:  0.9324324324324325

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
print(confusion_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='magma')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Predicted   0   1
# Actual
# 0          35   4
# 1           6  69

# %%
model_names = ['NB (No Scaling)', 'NB (Scaled)', 'NB (Normalized)']
accuracy_scores = [accuracy_score(y_pred, y_test), accuracy_score(y_pred_scaler, y_test), accuracy_score(y_pred_norm, y_test)]

plt.figure(figsize=(8, 6))
plt.bar(model_names, accuracy_scores, color=['maroon', 'red', 'black'])
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Comparison of SVM Models Accuracy')
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC

svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)

y_pred = svm_model.predict(X_test)

accuracy = accuracy_score(y_pred, y_test)
print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.9385964912280702

# %%
svm_model_scaled = SVC(kernel='linear')
svm_model_scaled.fit(X_train_scaled, y_train)
y_pred_scaled = svm_model_scaled.predict(X_test_scaled)

accuracy = accuracy_score(y_pred_scaled, y_test)
print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.9649122807017544

# %%
svm_model_norm = SVC(kernel='linear')
svm_model_norm.fit(X_train_normalized, y_train)
y_pred_norm = svm_model_norm.predict(X_test_normalized)

accuracy = accuracy_score(y_pred_norm, y_test)
print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.8596491228070176

# %%
import matplotlib.pyplot as plt
import seaborn as sns

confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
print(confusion_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='magma')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Predicted   0   1
# Actual
# 0          36   3
# 1           1  74

# %%
model_names = ['SVM (No Scaling)', 'SVM (Scaled)', 'SVM (Normalized)']
accuracy_scores = [accuracy_score(y_pred, y_test), accuracy_score(y_pred_scaled, y_test), accuracy_score(y_pred_norm, y_test)]

plt.figure(figsize=(8, 6))
plt.bar(model_names, accuracy_scores, color=['maroon', 'red', 'black'])
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Comparison of SVM Models Accuracy')
plt.ylim(0, 1)
plt.show()
